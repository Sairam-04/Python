# %% [markdown]
# <a href="https://colab.research.google.com/github/Sairam-04/Python/blob/main/Regex_and_Data_Extraction_from_Web_Pages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basic Programs

# %%
#Average of the numbers

#Using for loop :
print('Using For loop')
total = 0
count = 0
while True:
    inp = input("Enter a number:") # enter done if you want to stop giving inputs
    if(inp == 'done'):
        break
    value = float(inp)
    total = total+value
    count = count+1

average = total / count
print('Average is',average)
# Out:
# Using For loop
# Enter a number:5
# Enter a number:10
# Enter a number:15
# Enter a number:done
# Average is 10.0

# %%
#Using Lists :

print("Using lists")
numlist = list()
while True:
    inp1 = input("Enter a number")
    if(inp1 == 'done'):
        break
    value1 = float(inp1)
    numlist.append(value1)

average1 = sum(numlist)/len(numlist)
print("Average",average1)
# Out:
# Using lists
# Enter a number1
# Enter a number2
# Enter a number5
# Enter a number10
# Enter a numberdone
# Average 4.5

# %%
# Finding largest and smallest numbers:
largest = None
smallest = None
while True:
    num = input("Enter a number: ")
    if num == "done" :
        break

    try:
        ival = int(num)

    except:
        print("Invalid input")
        continue

    if smallest is None and largest is None:
        smallest = ival
        largest = ival
    if(smallest > ival):
        smallest = ival
    if(largest < ival):
    	largest = ival

print("Maximum is", largest)
print("Minimum is", smallest)
# Out:
# Enter a number: 10
# Enter a number: 20
# Enter a number: 30
# Enter a number: done
# Maximum is 30
# Minimum is 10

# %%
# Finding Gross pay
hours = input("enter hours:")
rate = input("enter rate:")
fhours = float(hours)
frate = float(rate)
if fhours > 40:
    Pay = (40 * frate) + (fhours - 40) * frate *1.5
    print(Pay)
else:
    Pay = fhours * frate
# Out:
# enter hours:50
# enter rate:2
# 110.0

# %%
#Finding largest number
large_num = -1
for i in [4,2,10,55,100,33,21,65,77,105,22,150,1,7]:
    if i > large_num:
        large_num = i
print("The largest number is :",large_num)
# Out:
# The largest number is : 150

# %% [markdown]
# # FILE OPERATIONS

# %%
# Reading files
fname = input("Enter file name: ")
fh = open(fname)
lst = list()
for line in fh:
	hline = line.rstrip()
	spline = hline.split()
	for iter in spline:
		if iter in lst:
			continue
		else:
			lst.append(iter)
lst.sort()
print(lst)
# Out:
# Enter file name: mbox-short.txt
# ...

# %%
# counting number of lines in a file
fname = input("Enter file name: ")
if len(fname) < 1 :
    fname = "mbox-short.txt"

fh = open(fname)
count = 0

for line in fh:
    lines = line.rstrip()
    if lines.startswith('From '):
        spline = lines.split()
        count = count+1
        print(spline[1])

print("There were", count, "lines in the file with From as the first word")
# Out:
# Enter file name:
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# zqian@umich.edu
# rjlowe@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# gsilver@umich.edu
# gsilver@umich.edu
# zqian@umich.edu
# gsilver@umich.edu
# wagnermr@iupui.edu
# zqian@umich.edu
# antranig@caret.cam.ac.uk
# gopal.ramasammycook@gmail.com
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# david.horwitz@uct.ac.za
# stephen.marquard@uct.ac.za
# louis@media.berkeley.edu
# louis@media.berkeley.edu
# ray@media.berkeley.edu
# cwen@iupui.edu
# cwen@iupui.edu
# cwen@iupui.edu
# There were 27 lines in the file with From as the first word

# %%
# Retriving data from file and taking the integer parts and doing the sum
fname = input("Enter file name: ")
fh = open(fname)
sum = 0.0
s = 0
for line in fh:
    if not line.startswith("X-DSPAM-Confidence:") :
         continue
    fl = float(line[20:])
    s=s+1
    sum = sum+fl

s = float(s)
print("sum:",sum)
print('average is ',sum/s)
# Out:
# Enter file name: mbox-short.txt
# sum: 20.269400000000005
# average is  0.7507185185185187

# %%
'''counting the number of required lines '''

file_name = input("enter the file name:")
try:
    sfile = open(file_name)
except:
    print("you have enteresd wrong file name",file_name,"please try again File does not exists")
    quit()

count = 0
for line in sfile:
    if(line.startswith("From")):
        count += 1
print("There were",count,"lines starting with Data in",sfile)
# Out:
# enter the file name:mbox-short.txt
# There were 54 lines starting with Data in <_io.TextIOWrapper name='mbox-short.txt' mode='r' encoding='UTF-8'>

# %%
# using dictonaries
fname = input('Enter a file name:')
if len(fname)<1:
    fname = 'mbox-short.txt'
fhand = open(fname)
counts = dict()  #Creating Dictonary

'''Creating a dictonary with words and no of times word repeated'''

for line in fhand:
#Splitting words in the dictonary
    wds = line.split()
    for word in wds:
        counts[word] = counts.get(word,0)+1
print(counts)
# Out:
# Enter a file name:
# ...

# %%
'''Using List comprehension method::'''
c = sorted([(v,k) for k,v in counts.items()],reverse = True)
print(c[:5])
# Out:
# [(352, 'Jan'), (324, '2008'), (245, 'by'), (243, 'Received:'), (219, '-0500')]

# %%
'''creating list and adding the tuples'''

lst = list()
for key,val in counts.items():
    newtup = (val,key)
    lst.append(newtup)

lst = sorted(lst,reverse = True)
#Printing top 5 words which are repeated more times
for val,key in lst[:5]:
    print(key,val)
# Out:
# Jan 352
# 2008 324
# by 245
# Received: 243
# -0500 219

# %%
fname = input('Enter a file name:')
if len(fname)<1:
    fname = 'mbox-short.txt'
fhand = open(fname)
counts = dict()
lst = list()
for line in fhand:
    if not line.startswith('From '):
        continue
    line = line.split()
    cds = line[5]
    wds = cds[:2]
    lst.append(wds)

for name in lst:
    counts[name] = counts.get(name,0) + 1
newlst = list()
for key,val in counts.items():
    newtup = (key,val)
    newlst.append(newtup)
newlst = sorted(newlst)
for k,v in newlst:
    print(k,v)
# Out:
# Enter a file name:
# 04 3
# 06 1
# 07 1
# 09 2
# 10 3
# 11 6
# 14 1
# 15 2
# 16 4
# 17 2
# 18 1
# 19 1

# %%
#Counting words in a list
count = dict()
names = ['Sairam','Dheeraj','Keerthi','Amaravathi','Narasingh','Sairam','Keerthi','Amaravathi','Keerthi','Sairam']
for name in names:
    if name not in count:
        count[name] = 1
    else:
        count[name] = count[name]+1
print(count)
# Out:
# {'Sairam': 3, 'Dheeraj': 1, 'Keerthi': 3, 'Amaravathi': 2, 'Narasingh': 1}

# %%
#Using get method
count[name] = count.get(name,0)+1
print(count)
# Out:
# {'Sairam': 5, 'Dheeraj': 1, 'Keerthi': 3, 'Amaravathi': 2, 'Narasingh': 1}

# %%
# Counting words in a file
name = input("Enter file:")
if len(name) < 1 : name = "mbox-short.txt"
handle = open(name)

lst = list()
for line in handle:
    if not line.startswith('From:'):
         continue
    line = line.split()
    lst.append(line[1])

counts = dict()
for name in lst:
    counts[name] = counts.get(name,0) + 1

print(counts.items())

bigcount = None
bigword  = None
for word,count in counts.items():
    if bigcount is None or count > bigcount:
        bigcount = count
        bigword = word

print(bigword,bigcount)
# Out:
# Enter file:
# dict_items([('stephen.marquard@uct.ac.za', 2), ('louis@media.berkeley.edu', 3), ('zqian@umich.edu', 4), ('rjlowe@iupui.edu', 2), ('cwen@iupui.edu', 5), ('gsilver@umich.edu', 3), ('wagnermr@iupui.edu', 1), ('antranig@caret.cam.ac.uk', 1), ('gopal.ramasammycook@gmail.com', 1), ('david.horwitz@uct.ac.za', 4), ('ray@media.berkeley.edu', 1)])
# cwen@iupui.edu 5

# %% [markdown]
# # Regular expressions

# %%
import re
s = "Hi i am sairam"
k = re.search("^Hi",s)
k
# Out:
# <_sre.SRE_Match object; span=(0, 2), match='Hi'>

# %%
import re

fname = "mbox-short.txt"
fhand = open(fname)
for line in fhand:
    line = line.rstrip()
    # ^ - indicates From at the begining of the line
    if re.search('^From: ', line):
        print(line)
# Out:
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: zqian@umich.edu
# From: rjlowe@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: gsilver@umich.edu
# From: gsilver@umich.edu
# From: zqian@umich.edu
# From: gsilver@umich.edu
# From: wagnermr@iupui.edu
# From: zqian@umich.edu
# From: antranig@caret.cam.ac.uk
# From: gopal.ramasammycook@gmail.com
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: david.horwitz@uct.ac.za
# From: stephen.marquard@uct.ac.za
# From: louis@media.berkeley.edu
# From: louis@media.berkeley.edu
# From: ray@media.berkeley.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu
# From: cwen@iupui.edu

# %%
import re
x = "My age is 18 and I was born on 4 April 2002"
y = re.findall('[0-9]+',x)
print(y)
# Out:
# ['18', '4', '2002']

# %%
import re
hand = open('mbox-short.txt')
numlist = list()
for line in hand:
    line = line.rstrip()
    stuff = re.findall('^X-DSPAM-Confidence: ([0-9.]+)',line)
    if len(stuff) != 1:
        continue
    num = float(stuff[0])
    numlist.append(num)

print("Maximum:",max(numlist))
# Out:
# Maximum: 0.9907

# %%
import re
name = input("Enter file:")
if len(name) < 1 : name = "regex_sum_42.txt"
handle = open(name)
x=list()
for line in handle:
    y=re.findall('[0-9]+',line)
    x = x+y
sum=0
for i in x:
    sum=sum + int(i)
print (sum)
# Out:
# Enter file:
# 445833

# %% [markdown]
# # Reading data from web pages

# %%
# Finding urls in a file
import urllib.request, urllib.parse,urllib.error
from bs4 import BeautifulSoup
import ssl

ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input("Enter : ")
html = urllib.request.urlopen(url,context = ctx).read()
soup = BeautifulSoup(html,'html.parser')

tags = soup('a')
for tag in tags:
    print(tag.get('href',None))

# %%
import requests
from bs4 import BeautifulSoup

keyword=input("Enter the product : ")

url="https://www.amazon.in/s?k="+keyword+"&ref=nb_sb_noss"
#url="https://www.snapdeal.com/search?keyword="+keyword+"&santizedKeyword=&catId=&categoryId=0&suggested=false&vertical=&noOfResults=20&searchState=&clickSrc=go_header&lastKeyword=&prodCatId=&changeBackToAll=false&foundInAll=false&categoryIdSearched=&cityPageUrl=&categoryUrl=&url=&utmContent=&dealDetail=&sort=rlvncy"

res=requests.get(url).content
#print(res)

soup=BeautifulSoup(res,'html')
#print(soup.text)


data=soup.find_all('div',class_="sg-col-inner")
#data=soup.find_all('p','product-title')
for product in data:
    print(product.text.strip()+"\n")
# Out:
# Enter the product : watch
# 1-16 of over 100,000 results for "watch"
#
#
#
# Skip to main search results
#
#
#
#
#
#
#
#
#
#
#
# Amazon Prime
#
#
#
#
#
#
#
#
#
#
#
#
# Pantry
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Department
#
#
#
#
# Watches
#
#
#
#
# Electronics
#
#
#
#
# Sports, Fitness & Outdoors
#
#
#
#
# Computers & Accessories
#
#
#
#
# Books
#
#
#
#
# Kindle Store
#
#
#
#
# Everything Else
#
#
#
#
# Prime Video
#
#
#
#
#
#
# Avg. Customer Review
#
#
#
#
#
# 4 Stars & Up
# & Up
#
#
#
#
#
#
# 3 Stars & Up
# & Up
#
#
#
#
#
#
# 2 Stars & Up
# & Up
#
#
#
#
#
#
# 1 Star & Up
# & Up
#
#
#
#
#
#
#
# Deals
#
#
#
#
#
# Today's Deals
#
#
#
#
#
#
# Subscription Option
#
#
#
#
#
# Subscribe & Save
#
#
#
#
# Pay On Delivery
#
#
#
#
#
# Eligible for Pay On Delivery
#
#
#
#
#
#
#
#
#
#
#
#
#  window.uet && uet('bb', 'searchSafeFrame:LEFT', {wb: 1});
#
#
#
#                 Advertisement
#
#
#  window.uet && uet('be', 'searchSafeFrame:LEFT', {wb: 1});
#
# ...

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter - ')
html = urlopen(url, context=ctx).read()
soup = BeautifulSoup(html, "html.parser")

# Retrieve all of the anchor tags
tags = soup('span')
sum = 0
for tag in tags:
    sum+=int(tag.contents[0])
print(sum)
# Out:
# Enter - http://py4e-data.dr-chuck.net/comments_42.html
# 2553

# %%
''' Using url lib for accessing data in a web page'''

import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen("http://data.pr4e.org/romeo.txt")
for line in fhand:
    print(line.decode().strip())
# Out:
# But soft what light through yonder window breaks
# It is the east and Juliet is the sun
# Arise fair sun and kill the envious moon
# Who is already sick and pale with grief

# %%
'''Using Networks and sockets for accessing data in a web page'''

import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/remeo.txt HTTP/1.0\n\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if len(data) < 1:
        break
    print(data.decode(),end='')

mysock.close()
# Out:
# HTTP/1.1 400 Bad Request
# Date: Sun, 23 Aug 2020 13:38:16 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Content-Length: 308
# Connection: close
# Content-Type: text/html; charset=iso-8859-1
#
# <!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML 2.0//EN">
# <html><head>
# <title>400 Bad Request</title>
# </head><body>
# <h1>Bad Request</h1>
# <p>Your browser sent a request that this server could not understand.<br />
# </p>
# <hr>
# <address>Apache/2.4.18 (Ubuntu) Server at do1.dr-chuck.com Port 80</address>
# </body></html>

# %%
import socket

mysock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
mysock.connect(('data.pr4e.org', 80))
cmd = 'GET http://data.pr4e.org/intro-short.txt HTTP/1.0\r\n\r\n'.encode()
mysock.send(cmd)

while True:
    data = mysock.recv(512)
    if len(data) < 1:
        break
    print(data.decode(),end='')

mysock.close()
# Out:
# HTTP/1.1 200 OK
# Date: Wed, 16 Sep 2020 07:31:50 GMT
# Server: Apache/2.4.18 (Ubuntu)
# Last-Modified: Sat, 13 May 2017 11:22:22 GMT
# ETag: "1d3-54f6609240717"
# Accept-Ranges: bytes
# Content-Length: 467
# Cache-Control: max-age=0, no-cache, no-store, must-revalidate
# Pragma: no-cache
# Expires: Wed, 11 Jan 1984 05:00:00 GMT
# Connection: close
# Content-Type: text/plain
#
# Why should you learn to write programs?
#
# Writing programs (or programming) is a very creative
# and rewarding activity.  You can write programs for
# many reasons, ranging from making your living to solving
# a difficult data analysis problem to having fun to helping
# someone else solve a problem.  This book assumes that
# everyone needs to know how to program, and that once
# you know how to program you will figure out what you want
# to do with your newfound skills.

# %%
""" Counting the number of words in a web page data"""
import urllib.request, urllib.parse, urllib.error

fhand = urllib.request.urlopen("http://data.pr4e.org/romeo.txt")
counts = dict()
for line in fhand:
    words = line.decode().split()
    for word in words:
        counts[word] = counts.get(word,0)+1

print(counts)
# Out:
# {'But': 1, 'soft': 1, 'what': 1, 'light': 1, 'through': 1, 'yonder': 1, 'window': 1, 'breaks': 1, 'It': 1, 'is': 3, 'the': 3, 'east': 1, 'and': 3, 'Juliet': 1, 'sun': 2, 'Arise': 1, 'fair': 1, 'kill': 1, 'envious': 1, 'moon': 1, 'Who': 1, 'already': 1, 'sick': 1, 'pale': 1, 'with': 1, 'grief': 1}

# %%
import urllib.request, urllib.parse, urllib.error
from bs4 import BeautifulSoup
import ssl

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

url = input('Enter URL:')
count = int(input("Enter count:"))
pos = int(input("Enter position:"))
print("Retriving :",url)
for i in range(0,count):
    html = urllib.request.urlopen(url).read()
    soup = BeautifulSoup(html, 'html.parser')
    tags = soup('a')
    url = tags[pos-1].get('href')  # To get the links in the first page
    print("Retriving :",url)

res = tags[pos-1].contents[0]
print(res)
# Out:
# Enter URL:http://py4e-data.dr-chuck.net/known_by_Fikret.html
# Enter count:7
# Enter position:5
# Retriving : http://py4e-data.dr-chuck.net/known_by_Fikret.html
# Retriving : http://py4e-data.dr-chuck.net/known_by_Haniyah.html
# Retriving : http://py4e-data.dr-chuck.net/known_by_Amii.html
# Retriving : http://py4e-data.dr-chuck.net/known_by_Holly.html
# Retriving : http://py4e-data.dr-chuck.net/known_by_Arda.html
# Retriving : http://py4e-data.dr-chuck.net/known_by_Tammylee.html
# Retriving : http://py4e-data.dr-chuck.net/known_by_Macaully.html
# Retriving : http://py4e-data.dr-chuck.net/known_by_Lockey.html
# Lockey

# %%
# Reading data from xml page
import xml.etree.ElementTree as ET

data = '''<person>
    <name>Sairam</name>
    <phone type = "intl">9390708854</phone>
    <email hide = "sairam3542@gmail.com"/>
</person>'''

tree = ET.fromstring(data)
print("Name :",tree.find('name').text)
print("Phone :",tree.find('phone').text)
print("email :",tree.find('email').get('hide'))
# Out:
# Name : Sairam
# Phone : 9390708854
# email : sairam3542@gmail.com

# %%
import xml.etree.ElementTree as ET

data = '''<stuff>
    <users>
        <user x = "1">
            <id>542</id>
            <name>R.Sairam</name>
        </user>
        <user x = "2">
            <id>518</id>
            <name>G.Hemanth sai</name>
        </user>
    </users>
</stuff>'''

stuff = ET.fromstring(data)
lst = stuff.findall('users/user')
print("Users count",len(lst))
for item in lst:
    print("Name:",item.find('name').text)
    print("ID:",item.find('id').text)
    print("Attribute:",item.get('x'))
# Out:
# Users count 2
# Name: R.Sairam
# ID: 542
# Attribute: 1
# Name: G.Hemanth sai
# ID: 518
# Attribute: 2

# %%
# Reading data from JSON
import json
data ='''{
    "name":"Sairam",
    "phone":{
    "type":"intl",
    "number":"9390708854"
    },
    "email":{
      "hide":"yes"
    }
}'''
info = json.loads(data)
print(info["name"])
# Out:
# Sairam

# %%
import json
inp ='''
[
  {
    "name":"Sairam",
    "id":"001"
  },
  {
    "name":"hemanth",
    "id":"002"
  }

]
'''
inf = json.loads(inp)
for i in inf:
  print(i['name'],i['id'])
# Out:
# Sairam 001
# hemanth 002

# %%
import urllib.request, urllib.parse, urllib.error
import xml.etree.ElementTree as ET
import ssl

api_key = False

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/xml?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/xml?'

ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

sum = 0
count = 0


while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)
    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)

    data = uh.read()
    print('Retrieved', len(data), 'characters')
    print(data.decode())
    tree = ET.fromstring(data)

    results = tree.findall('comments/comment')
    for item in results:
        x = item.find('count')
        count+=1
        sum+=x

    print("Count:",count)
    print('Sum:',sum)
# Out:
# Enter Location:http://py4e-data.dr-chuck.net/comments_42.xml
# Retriving http://py4e-data.dr-chuck.net/comments_42.xml
# Retrived 50 characters
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-ff8f71493697> in <module>()
#      16     x = item.find('count')
#      17     count = count+1
# ---> 18     sum += x
#      19 print("Count :",count)
#      20 print("Sum :",sum)
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'xml.etree.ElementTree.Element'

# %%
import urllib.request, urllib.parse, urllib.error
import json

serviceurl = "http://maps.googleapis.com/maps/api/geocode/json?"

while True:
  address = input("enter location:")
  if len(address) < 1:  break

  url = serviceurl + urllib.parse.urlencode({'address':address})

  print("Retrieving:",url)
  uh = urllib.request.urlopen(url)
  data = uh.read().decode()
  print("Retrieved",len(data),'characters')

  try:
    js = json.loads(data)
  except:
    js = None

  if not js or 'status' not in js or js['status'] != 'OK':
    print('Failed to retrive...')
    print(data)
    continue

  print(json.dumps(js,indent=4))
  lat = js['results'][0]['geometry']['location']['lat']
  lng = js['results'][0]['geometry']['location']['lng']
  print('lat:',lat,'lng',lng)
  location = js['results'][0]['formatted_address']
  print(location)
# Out:
# enter location:Ann Arbor, MI
# Retrieving: http://maps.googleapis.com/maps/api/geocode/json?address=Ann+Arbor%2C+MI
# Retrieved 237 characters
# Failed to retrive...
# {
#    "error_message" : "You must use an API key to authenticate each request to Google Maps Platform APIs. For additional information, please refer to http://g.co/dev/maps-no-account",
#    "results" : [],
#    "status" : "REQUEST_DENIED"
# }
#
# enter location:

# %%
# Retriving data from Google geocode API

import urllib.request, urllib.parse, urllib.error
import json
import ssl

api_key = False
# If you have a Google Places API key, enter it here
# api_key = 'AIzaSy___IDByT70'
# https://developers.google.com/maps/documentation/geocoding/intro

if api_key is False:
    api_key = 42
    serviceurl = 'http://py4e-data.dr-chuck.net/json?'
else :
    serviceurl = 'https://maps.googleapis.com/maps/api/geocode/json?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    address = input('Enter location: ')
    if len(address) < 1: break

    parms = dict()
    parms['address'] = address
    if api_key is not False: parms['key'] = api_key
    url = serviceurl + urllib.parse.urlencode(parms)

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    if not js or 'status' not in js or js['status'] != 'OK':
        print('==== Failure To Retrieve ====')
        print(data)
        continue

    print(json.dumps(js, indent=4))
    #dictionary that contains a list, a list of dictionaries, and dictionary within dictionary within dictionary

    lat = js['results'][0]['geometry']['location']['lat']
    lng = js['results'][0]['geometry']['location']['lng']
    print('lat', lat, 'lng', lng)
    location = js['results'][0]['formatted_address']
    print(location)
# Out:
# Enter location: Ann Arbor, MI
# Retrieving http://py4e-data.dr-chuck.net/json?address=Ann+Arbor%2C+MI&key=42
# Retrieved 1736 characters
# {
#     "results": [
#         {
#             "address_components": [
#                 {
#                     "long_name": "Ann Arbor",
#                     "short_name": "Ann Arbor",
#                     "types": [
#                         "locality",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Washtenaw County",
#                     "short_name": "Washtenaw County",
#                     "types": [
#                         "administrative_area_level_2",
#                         "political"
#                     ]
#                 },
#                 {
#                     "long_name": "Michigan",
#                     "short_name": "MI",
#                     "types": [
#                         "administrative_area_level_1",
# ...

# %%
import urllib.request, urllib.parse, urllib.error
from twurl import augment
import ssl

# https://apps.twitter.com/
# Create App and get the four strings, put them in hidden.py

print('* Calling Twitter...')
url = augment('https://api.twitter.com/1.1/statuses/user_timeline.json',
              {'screen_name': 'drchuck', 'count': '2'})
print(url)

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

connection = urllib.request.urlopen(url, context=ctx)
data = connection.read()
print(data)

print ('======================================')
headers = dict(connection.getheaders())
print(headers)

# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl

counts = list()
while True:
    address =input('Enter location')
    if len(address) < 1 : break
    print ('Retrieving', address)
    connection = urllib.request.urlopen(address, context=ctx)
    data = connection.read()
    print ('Retrieved',len(data),'characters')
    try:
      js = json.loads(data)
    except:
      js = None
    comments = js['comments']
    for comment in comments:
        counts.append(comment['count'])
    print ('Count', len(comments))
    print ('Sum', sum(counts))
# Out:
# Enter locationhttp://py4e-data.dr-chuck.net/comments_922230.json
# Retrieving http://py4e-data.dr-chuck.net/comments_922230.json
# Retrieved 2727 characters
# Count 50
# Sum 2527
# Enter location

# %%
import urllib.request, urllib.parse, urllib.error
import json
import ssl


serviceurl = 'http://python-data.dr-chuck.net/geojson?'

# Ignore SSL certificate errors
ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

while True:
    address = input('Enter location: ')
    if len(address) < 1: break
    url = serviceurl + urllib.parse.urlencode({'sensor':'false','address':address})

    print('Retrieving', url)
    uh = urllib.request.urlopen(url, context=ctx)
    data = uh.read().decode()
    print('Retrieved', len(data), 'characters')

    try:
        js = json.loads(data)
    except:
        js = None

    location = js["results"][0]["place_id"]
    print(location)
# Out:
# Enter location: South Federal University
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=South+Federal+University
# Retrieved 2101 characters
# ChIJJ8oO7_B_bIcR2AlhC8nKlok
# Enter location: universidad complutense de madrid
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=universidad+complutense+de+madrid
# Retrieved 1929 characters
# ChIJ603MhzQoQg0R6QV5ZUokpOc
# Enter location:

# %%
import urllib.request, urllib.parse, urllib.error
import json

serviceurl = 'http://python-data.dr-chuck.net/geojson?'
while True:
    address =input('Enter location: ')
    if len(address) < 1 : break
    url = serviceurl + urllib.parse.urlencode({'sensor':'false', 'address': address})
    print ('Retrieving', url)
    uh = urllib.request.urlopen(url)
    data = uh.read().decode()
    print ('Retrieved',len(data),'characters')
    try: js = json.loads(str(data))
    except: js = None
    print ('Place ID ', js["results"][0]["place_id"])
# Out:
# Enter location: universidad complutense de madrid
# Retrieving http://python-data.dr-chuck.net/geojson?sensor=false&address=universidad+complutense+de+madrid
# Retrieved 1929 characters
# Place ID  ChIJ603MhzQoQg0R6QV5ZUokpOc
# Enter location:

# %%
import urllib.request as ur
import urllib.parse as up
import json

serviceurl = "http://python-data.dr-chuck.net/geojson?"

address_input = input("Enter location: ")
params = {"sensor": "false", "address": address_input}
url = serviceurl + up.urlencode(params)
print("Retrieving ", url)
data = ur.urlopen(url).read().decode('utf-8')
print('Retrieved', len(data), 'characters')
json_obj = json.loads(data)

place_id = json_obj["results"][0]["place_id"]
print("Place id", place_id)
# Out:
# Enter location: universidad complutense de madrid
# Retrieving  http://python-data.dr-chuck.net/geojson?sensor=false&address=universidad+complutense+de+madrid
# Retrieved 1929 characters
# Place id ChIJ603MhzQoQg0R6QV5ZUokpOc

# %%
import urllib.request, urllib.parse, urllib.error
import json

#Api
api = 'http://py4e-data.dr-chuck.net/geojson?'

#Input data
link = input('Enter location: ')
link = api + urllib.parse.urlencode({'address':link,'key':42})
print('Retrieving', link)

html = urllib.request.urlopen(link).read().decode()
print('Retrieved', len(html), 'characters')

try:
    js = json.loads(html)
except:
    js = None

placeId = js['results'][0]['place_id']
print('Place id', placeId)
# Out:
# Enter location: South Federal University
# Retrieving http://py4e-data.dr-chuck.net/geojson?address=South+Federal+University&key=42
# Retrieved 2101 characters
# Place id ChIJJ8oO7_B_bIcR2AlhC8nKlok

# %%
import urllib.request as ur
import urllib.parse as up
import json

serviceurl = "http://py4e-data.dr-chuck.net/json?key=42&"

address_input = input('Enter location:')
params = {'sensor':'false','address':address_input}
url = serviceurl+ up.urlencode(params)

print('Retrieving',url)
data = ur.urlopen(url).read().decode('utf-8')
print("Retrieved",len(data),'characters')
js = json.loads(data)

place_id = js["results"][0]["place_id"]
print("Place id",place_id)
# Out:
# Enter location:universidad complutense de madrid
# Retrieving http://py4e-data.dr-chuck.net/json?key=42&sensor=false&address=universidad+complutense+de+madrid
# Retrieved 2083 characters
# Place id ChIJd7ZpUT8oQg0R33DgLxuaZN4

# %%
import nltk.corpus
